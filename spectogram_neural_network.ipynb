# %%
import librosa
import pandas
import numpy as np
import matplotlib.pyplot as plot
import pathlib
from pathlib import Path
import os
import random
from datetime import datetime
import cv2

# %%
def getGenreFromPath(path):
    split_name = str(path.name).split(".")
    return path.parts[-2]

# %%
data_folder = Path("../../audio/testfiles/GTZAN/genres/")
spectogram_folder = Path("./img_data/")
#duration of songsnippet in seconds
duration = 10
#matplotlib colormap for spectogram
spectogram_cmap = 'binary' 
#predefined list of genres
pred_genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split() 
#imagePaths = sorted(list(spectogram_folder.list_images(args["dataset"])))
#imagePaths

# %%
#Get directories of all songs
songs = []
genres = []

spectograms = []

for g in data_folder.iterdir():
    genres.append(g.name)
    for i in g.iterdir():
        songs.append(i)

# %%
#Calculate all spectograms
cmap = plot.get_cmap(spectogram_cmap)
plot.figure(figsize=(10,10))
spectograms = []

#Iterate through all songs and generate their spactograms. Save them all as images.
for genre in genres:
    pathlib.Path(f'img_data/{genre}').mkdir(parents=True, exist_ok=True)     
for song in songs:
    y, sr = librosa.load(song, mono=True, duration=duration)
    plot.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
    plot.axis('off');
    spec_path = pathlib.Path(f'img_data/{getGenreFromPath(song)}/{".".join(str(song.parts[-1]).split(".")[:2])}.png')
    spectograms.append(spec_path)
    plot.savefig(spec_path)
    plot.clf()

# %%
#Seed for RNG
random.seed(datetime.now())

# %%
#Shuffle the spectograms
random.shuffle(spectograms)
spectograms
# Out:
# [PosixPath('img_data/reggae/reggae.00057.png'),
#  PosixPath('img_data/jazz/jazz.00087.png'),
#  PosixPath('img_data/reggae/reggae.00096.png'),
#  PosixPath('img_data/rock/rock.00044.png'),
#  PosixPath('img_data/rock/rock.00065.png'),
#  PosixPath('img_data/blues/blues.00029.png'),
#  PosixPath('img_data/disco/disco.00032.png'),
#  PosixPath('img_data/hiphop/hiphop.00093.png'),
#  PosixPath('img_data/rock/rock.00040.png'),
#  PosixPath('img_data/reggae/reggae.00045.png'),
#  PosixPath('img_data/jazz/jazz.00022.png'),
#  PosixPath('img_data/disco/disco.00098.png'),
#  PosixPath('img_data/classical/classical.00097.png'),
#  PosixPath('img_data/reggae/reggae.00047.png'),
#  PosixPath('img_data/country/country.00079.png'),
#  PosixPath('img_data/hiphop/hiphop.00013.png'),
#  PosixPath('img_data/metal/metal.00004.png'),
#  PosixPath('img_data/jazz/jazz.00056.png'),
#  PosixPath('img_data/pop/pop.00046.png'),
#  PosixPath('img_data/metal/metal.00084.png'),
#  PosixPath('img_data/rock/rock.00050.png'),
#  PosixPath('img_data/classical/classical.00074.png'),
#  PosixPath('img_data/metal/metal.00026.png'),
#  PosixPath('img_data/metal/metal.00062.png'),
#  PosixPath('img_data/pop/pop.00044.png'),
#  PosixPath('img_data/jazz/jazz.00092.png'),
#  PosixPath('img_data/jazz/jazz.00047.png'),
#  PosixPath('img_data/classical/classical.00025.png'),
#  PosixPath('img_data/jazz/jazz.00033.png'),
#  PosixPath('img_data/metal/metal.00098.png'),
#  PosixPath('img_data/blues/blues.00033.png'),
#  PosixPath('img_data/classical/classical.00098.png'),
#  PosixPath('img_data/classical/classical.00012.png'),
#  PosixPath('img_data/pop/pop.00047.png'),
#  PosixPath('img_data/blues/blues.00067.png'),
#  PosixPath('img_data/country/country.00078.png'),
#  PosixPath('img_data/disco/disco.00001.png'),
#  PosixPath('img_data/jazz/jazz.00064.png'),
#  PosixPath('img_data/metal/metal.00023.png'),
#  PosixPath('img_data/reggae/reggae.00087.png'),
#  PosixPath('img_data/classical/classical.00040.png'),
#  PosixPath('img_data/classical/classical.00049.png'),
#  PosixPath('img_data/classical/classical.00017.png'),
#  PosixPath('img_data/reggae/reggae.00052.png'),
#  PosixPath('img_data/classical/classical.00032.png'),
#  PosixPath('img_data/country/country.00027.png'),
#  PosixPath('img_data/pop/pop.00056.png'),
#  PosixPath('img_data/reggae/reggae.00008.png'),
#  PosixPath('img_data/reggae/reggae.00082.png'),
#  PosixPath('img_data/hiphop/hiphop.00018.png'),
#  PosixPath('img_data/jazz/jazz.00051.png'),
#  PosixPath('img_data/country/country.00071.png'),
#  PosixPath('img_data/pop/pop.00094.png'),
#  PosixPath('img_data/country/country.00063.png'),
#  PosixPath('img_data/pop/pop.00041.png'),
#  PosixPath('img_data/hiphop/hiphop.00043.png'),
#  PosixPath('img_data/blues/blues.00040.png'),
#  PosixPath('img_data/country/country.00006.png'),
#  PosixPath('img_data/pop/pop.00005.png'),
#  PosixPath('img_data/reggae/reggae.00072.png'),
#  PosixPath('img_data/country/country.00047.png'),
#  PosixPath('img_data/metal/metal.00079.png'),
#  PosixPath('img_data/disco/disco.00025.png'),
#  PosixPath('img_data/reggae/reggae.00070.png'),
#  PosixPath('img_data/hiphop/hiphop.00046.png'),
#  PosixPath('img_data/metal/metal.00021.png'),
#  PosixPath('img_data/blues/blues.00087.png'),
#  PosixPath('img_data/jazz/jazz.00098.png'),
#  PosixPath('img_data/classical/classical.00043.png'),
#  PosixPath('img_data/blues/blues.00072.png'),
#  PosixPath('img_data/blues/blues.00019.png'),
#  PosixPath('img_data/rock/rock.00083.png'),
#  PosixPath('img_data/blues/blues.00057.png'),
#  PosixPath('img_data/hiphop/hiphop.00072.png'),
#  PosixPath('img_data/jazz/jazz.00041.png'),
#  PosixPath('img_data/hiphop/hiphop.00002.png'),
#  PosixPath('img_data/disco/disco.00064.png'),
#  PosixPath('img_data/rock/rock.00032.png'),
#  PosixPath('img_data/metal/metal.00085.png'),
#  PosixPath('img_data/classical/classical.00068.png'),
#  PosixPath('img_data/hiphop/hiphop.00015.png'),
#  PosixPath('img_data/classical/classical.00066.png'),
#  PosixPath('img_data/country/country.00019.png'),
#  PosixPath('img_data/rock/rock.00077.png'),
#  PosixPath('img_data/hiphop/hiphop.00052.png'),
#  PosixPath('img_data/hiphop/hiphop.00021.png'),
#  PosixPath('img_data/metal/metal.00087.png'),
#  PosixPath('img_data/hiphop/hiphop.00011.png'),
#  PosixPath('img_data/disco/disco.00030.png'),
#  PosixPath('img_data/hiphop/hiphop.00065.png'),
#  PosixPath('img_data/rock/rock.00095.png'),
#  PosixPath('img_data/classical/classical.00056.png'),
#  PosixPath('img_data/blues/blues.00092.png'),
#  PosixPath('img_data/disco/disco.00099.png'),
#  PosixPath('img_data/pop/pop.00033.png'),
#  PosixPath('img_data/country/country.00041.png'),
#  PosixPath('img_data/metal/metal.00007.png'),
#  PosixPath('img_data/blues/blues.00081.png'),
#  PosixPath('img_data/hiphop/hiphop.00050.png'),
#  PosixPath('img_data/hiphop/hiphop.00097.png'),
#  PosixPath('img_data/classical/classical.00067.png'),
#  PosixPath('img_data/hiphop/hiphop.00040.png'),
#  PosixPath('img_data/country/country.00073.png'),
#  PosixPath('img_data/classical/classical.00048.png'),
#  PosixPath('img_data/country/country.00076.png'),
#  PosixPath('img_data/metal/metal.00074.png'),
#  PosixPath('img_data/rock/rock.00020.png'),
#  PosixPath('img_data/classical/classical.00041.png'),
#  PosixPath('img_data/classical/classical.00001.png'),
#  PosixPath('img_data/metal/metal.00082.png'),
#  PosixPath('img_data/rock/rock.00052.png'),
#  PosixPath('img_data/metal/metal.00091.png'),
#  PosixPath('img_data/pop/pop.00057.png'),
#  PosixPath('img_data/rock/rock.00034.png'),
#  PosixPath('img_data/country/country.00044.png'),
#  PosixPath('img_data/country/country.00087.png'),
#  PosixPath('img_data/classical/classical.00099.png'),
#  PosixPath('img_data/disco/disco.00017.png'),
#  PosixPath('img_data/rock/rock.00037.png'),
#  PosixPath('img_data/classical/classical.00085.png'),
#  PosixPath('img_data/rock/rock.00012.png'),
#  PosixPath('img_data/pop/pop.00092.png'),
#  PosixPath('img_data/pop/pop.00058.png'),
#  PosixPath('img_data/blues/blues.00065.png'),
#  PosixPath('img_data/hiphop/hiphop.00069.png'),
#  PosixPath('img_data/pop/pop.00035.png'),
#  PosixPath('img_data/jazz/jazz.00043.png'),
#  PosixPath('img_data/blues/blues.00073.png'),
#  PosixPath('img_data/country/country.00038.png'),
#  PosixPath('img_data/metal/metal.00017.png'),
#  PosixPath('img_data/reggae/reggae.00083.png'),
#  PosixPath('img_data/reggae/reggae.00000.png'),
#  PosixPath('img_data/disco/disco.00028.png'),
#  PosixPath('img_data/blues/blues.00044.png'),
#  PosixPath('img_data/pop/pop.00050.png'),
#  PosixPath('img_data/jazz/jazz.00050.png'),
#  PosixPath('img_data/rock/rock.00089.png'),
#  PosixPath('img_data/country/country.00097.png'),
#  PosixPath('img_data/pop/pop.00020.png'),
#  PosixPath('img_data/country/country.00032.png'),
#  PosixPath('img_data/rock/rock.00081.png'),
#  PosixPath('img_data/reggae/reggae.00001.png'),
#  PosixPath('img_data/country/country.00065.png'),
#  PosixPath('img_data/jazz/jazz.00004.png'),
#  PosixPath('img_data/classical/classical.00053.png'),
#  PosixPath('img_data/pop/pop.00004.png'),
#  PosixPath('img_data/metal/metal.00069.png'),
#  PosixPath('img_data/country/country.00003.png'),
#  PosixPath('img_data/pop/pop.00064.png'),
#  PosixPath('img_data/disco/disco.00050.png'),
#  PosixPath('img_data/rock/rock.00022.png'),
#  PosixPath('img_data/disco/disco.00051.png'),
#  PosixPath('img_data/jazz/jazz.00006.png'),
#  PosixPath('img_data/disco/disco.00093.png'),
#  PosixPath('img_data/metal/metal.00005.png'),
#  PosixPath('img_data/classical/classical.00005.png'),
#  PosixPath('img_data/rock/rock.00098.png'),
#  PosixPath('img_data/jazz/jazz.00023.png'),
#  PosixPath('img_data/rock/rock.00041.png'),
#  PosixPath('img_data/rock/rock.00003.png'),
#  PosixPath('img_data/reggae/reggae.00085.png'),
#  PosixPath('img_data/pop/pop.00039.png'),
#  PosixPath('img_data/country/country.00067.png'),
#  PosixPath('img_data/reggae/reggae.00009.png'),
#  PosixPath('img_data/jazz/jazz.00001.png'),
#  PosixPath('img_data/reggae/reggae.00059.png'),
#  PosixPath('img_data/reggae/reggae.00095.png'),
#  PosixPath('img_data/hiphop/hiphop.00082.png'),
#  PosixPath('img_data/blues/blues.00088.png'),
#  PosixPath('img_data/metal/metal.00081.png'),
#  PosixPath('img_data/reggae/reggae.00062.png'),
#  PosixPath('img_data/metal/metal.00061.png'),
#  PosixPath('img_data/metal/metal.00022.png'),
#  PosixPath('img_data/country/country.00082.png'),
#  PosixPath('img_data/country/country.00099.png'),
#  PosixPath('img_data/metal/metal.00096.png'),
#  PosixPath('img_data/jazz/jazz.00075.png'),
#  PosixPath('img_data/blues/blues.00058.png'),
#  PosixPath('img_data/hiphop/hiphop.00055.png'),
#  PosixPath('img_data/disco/disco.00096.png'),
#  PosixPath('img_data/classical/classical.00084.png'),
#  PosixPath('img_data/rock/rock.00066.png'),
#  PosixPath('img_data/jazz/jazz.00074.png'),
#  PosixPath('img_data/reggae/reggae.00094.png'),
#  PosixPath('img_data/hiphop/hiphop.00045.png'),
#  PosixPath('img_data/rock/rock.00059.png'),
#  PosixPath('img_data/disco/disco.00089.png'),
#  PosixPath('img_data/reggae/reggae.00036.png'),
#  PosixPath('img_data/rock/rock.00099.png'),
#  PosixPath('img_data/jazz/jazz.00019.png'),
#  PosixPath('img_data/rock/rock.00068.png'),
#  PosixPath('img_data/pop/pop.00091.png'),
#  PosixPath('img_data/classical/classical.00008.png'),
#  PosixPath('img_data/disco/disco.00082.png'),
#  PosixPath('img_data/reggae/reggae.00081.png'),
#  PosixPath('img_data/disco/disco.00011.png'),
#  PosixPath('img_data/hiphop/hiphop.00067.png'),
#  PosixPath('img_data/pop/pop.00062.png'),
#  PosixPath('img_data/rock/rock.00016.png'),
#  PosixPath('img_data/rock/rock.00000.png'),
#  PosixPath('img_data/rock/rock.00072.png'),
#  PosixPath('img_data/blues/blues.00095.png'),
#  PosixPath('img_data/pop/pop.00084.png'),
#  PosixPath('img_data/disco/disco.00087.png'),
#  PosixPath('img_data/rock/rock.00064.png'),
#  PosixPath('img_data/hiphop/hiphop.00006.png'),
#  PosixPath('img_data/jazz/jazz.00031.png'),
#  PosixPath('img_data/metal/metal.00041.png'),
#  PosixPath('img_data/rock/rock.00029.png'),
#  PosixPath('img_data/classical/classical.00055.png'),
#  PosixPath('img_data/rock/rock.00002.png'),
#  PosixPath('img_data/classical/classical.00047.png'),
#  PosixPath('img_data/reggae/reggae.00055.png'),
#  PosixPath('img_data/jazz/jazz.00005.png'),
#  PosixPath('img_data/metal/metal.00086.png'),
#  PosixPath('img_data/jazz/jazz.00085.png'),
#  PosixPath('img_data/rock/rock.00042.png'),
#  PosixPath('img_data/reggae/reggae.00019.png'),
#  PosixPath('img_data/jazz/jazz.00069.png'),
#  PosixPath('img_data/rock/rock.00007.png'),
#  PosixPath('img_data/pop/pop.00015.png'),
#  PosixPath('img_data/blues/blues.00099.png'),
#  PosixPath('img_data/metal/metal.00008.png'),
#  PosixPath('img_data/rock/rock.00094.png'),
#  PosixPath('img_data/disco/disco.00084.png'),
#  PosixPath('img_data/pop/pop.00049.png'),
#  PosixPath('img_data/metal/metal.00011.png'),
#  PosixPath('img_data/rock/rock.00030.png'),
#  PosixPath('img_data/blues/blues.00053.png'),
#  PosixPath('img_data/rock/rock.00093.png'),
#  PosixPath('img_data/country/country.00022.png'),
#  PosixPath('img_data/reggae/reggae.00004.png'),
#  PosixPath('img_data/disco/disco.00086.png'),
#  PosixPath('img_data/reggae/reggae.00038.png'),
#  PosixPath('img_data/disco/disco.00078.png'),
#  PosixPath('img_data/blues/blues.00083.png'),
#  PosixPath('img_data/country/country.00074.png'),
#  PosixPath('img_data/reggae/reggae.00046.png'),
#  PosixPath('img_data/jazz/jazz.00089.png'),
#  PosixPath('img_data/country/country.00054.png'),
#  PosixPath('img_data/pop/pop.00061.png'),
#  PosixPath('img_data/hiphop/hiphop.00063.png'),
#  PosixPath('img_data/blues/blues.00080.png'),
#  PosixPath('img_data/pop/pop.00016.png'),
#  PosixPath('img_data/classical/classical.00094.png'),
#  PosixPath('img_data/rock/rock.00074.png'),
#  PosixPath('img_data/metal/metal.00015.png'),
#  PosixPath('img_data/country/country.00080.png'),
#  PosixPath('img_data/jazz/jazz.00045.png'),
#  PosixPath('img_data/metal/metal.00072.png'),
#  PosixPath('img_data/reggae/reggae.00021.png'),
#  PosixPath('img_data/reggae/reggae.00041.png'),
#  PosixPath('img_data/jazz/jazz.00046.png'),
#  PosixPath('img_data/blues/blues.00050.png'),
#  PosixPath('img_data/blues/blues.00051.png'),
#  PosixPath('img_data/reggae/reggae.00031.png'),
#  PosixPath('img_data/reggae/reggae.00034.png'),
#  PosixPath('img_data/classical/classical.00070.png'),
#  PosixPath('img_data/blues/blues.00064.png'),
#  PosixPath('img_data/metal/metal.00038.png'),
#  PosixPath('img_data/reggae/reggae.00044.png'),
#  PosixPath('img_data/blues/blues.00004.png'),
#  PosixPath('img_data/metal/metal.00078.png'),
#  PosixPath('img_data/rock/rock.00043.png'),
#  PosixPath('img_data/reggae/reggae.00049.png'),
#  PosixPath('img_data/rock/rock.00090.png'),
#  PosixPath('img_data/rock/rock.00025.png'),
#  PosixPath('img_data/hiphop/hiphop.00032.png'),
#  PosixPath('img_data/country/country.00085.png'),
#  PosixPath('img_data/jazz/jazz.00042.png'),
#  PosixPath('img_data/disco/disco.00027.png'),
#  PosixPath('img_data/pop/pop.00083.png'),
#  PosixPath('img_data/rock/rock.00045.png'),
#  PosixPath('img_data/rock/rock.00058.png'),
#  PosixPath('img_data/jazz/jazz.00029.png'),
#  PosixPath('img_data/rock/rock.00010.png'),
#  PosixPath('img_data/hiphop/hiphop.00020.png'),
#  PosixPath('img_data/disco/disco.00047.png'),
#  PosixPath('img_data/hiphop/hiphop.00005.png'),
#  PosixPath('img_data/hiphop/hiphop.00023.png'),
#  PosixPath('img_data/jazz/jazz.00079.png'),
#  PosixPath('img_data/country/country.00033.png'),
#  PosixPath('img_data/metal/metal.00075.png'),
#  PosixPath('img_data/blues/blues.00078.png'),
#  PosixPath('img_data/blues/blues.00059.png'),
#  PosixPath('img_data/jazz/jazz.00034.png'),
#  PosixPath('img_data/disco/disco.00091.png'),
#  PosixPath('img_data/metal/metal.00066.png'),
#  PosixPath('img_data/classical/classical.00072.png'),
#  PosixPath('img_data/classical/classical.00042.png'),
#  PosixPath('img_data/pop/pop.00031.png'),
#  PosixPath('img_data/country/country.00005.png'),
#  PosixPath('img_data/classical/classical.00028.png'),
#  PosixPath('img_data/classical/classical.00087.png'),
#  PosixPath('img_data/disco/disco.00038.png'),
#  PosixPath('img_data/hiphop/hiphop.00031.png'),
#  PosixPath('img_data/hiphop/hiphop.00088.png'),
#  PosixPath('img_data/disco/disco.00074.png'),
#  PosixPath('img_data/jazz/jazz.00003.png'),
#  PosixPath('img_data/country/country.00091.png'),
#  PosixPath('img_data/jazz/jazz.00025.png'),
#  PosixPath('img_data/pop/pop.00059.png'),
#  PosixPath('img_data/pop/pop.00097.png'),
#  PosixPath('img_data/blues/blues.00008.png'),
#  PosixPath('img_data/reggae/reggae.00053.png'),
#  PosixPath('img_data/pop/pop.00018.png'),
#  PosixPath('img_data/metal/metal.00090.png'),
#  PosixPath('img_data/rock/rock.00009.png'),
#  PosixPath('img_data/jazz/jazz.00024.png'),
#  PosixPath('img_data/classical/classical.00010.png'),
#  PosixPath('img_data/disco/disco.00085.png'),
#  PosixPath('img_data/country/country.00029.png'),
#  PosixPath('img_data/classical/classical.00003.png'),
#  PosixPath('img_data/classical/classical.00004.png'),
#  PosixPath('img_data/jazz/jazz.00016.png'),
#  PosixPath('img_data/blues/blues.00048.png'),
#  PosixPath('img_data/country/country.00072.png'),
#  PosixPath('img_data/pop/pop.00065.png'),
#  PosixPath('img_data/classical/classical.00065.png'),
#  PosixPath('img_data/metal/metal.00009.png'),
#  PosixPath('img_data/metal/metal.00003.png'),
#  PosixPath('img_data/blues/blues.00007.png'),
#  PosixPath('img_data/blues/blues.00013.png'),
#  PosixPath('img_data/pop/pop.00076.png'),
#  PosixPath('img_data/metal/metal.00039.png'),
#  PosixPath('img_data/hiphop/hiphop.00080.png'),
#  PosixPath('img_data/classical/classical.00039.png'),
#  PosixPath('img_data/rock/rock.00051.png'),
#  PosixPath('img_data/classical/classical.00007.png'),
#  PosixPath('img_data/classical/classical.00030.png'),
#  PosixPath('img_data/reggae/reggae.00090.png'),
#  PosixPath('img_data/disco/disco.00026.png'),
#  PosixPath('img_data/metal/metal.00073.png'),
#  PosixPath('img_data/reggae/reggae.00067.png'),
#  PosixPath('img_data/rock/rock.00049.png'),
#  PosixPath('img_data/country/country.00062.png'),
#  PosixPath('img_data/country/country.00001.png'),
#  PosixPath('img_data/pop/pop.00073.png'),
#  PosixPath('img_data/blues/blues.00028.png'),
#  PosixPath('img_data/blues/blues.00060.png'),
#  PosixPath('img_data/jazz/jazz.00059.png'),
#  PosixPath('img_data/disco/disco.00013.png'),
#  PosixPath('img_data/classical/classical.00019.png'),
#  PosixPath('img_data/rock/rock.00038.png'),
#  PosixPath('img_data/reggae/reggae.00048.png'),
#  PosixPath('img_data/rock/rock.00046.png'),
#  PosixPath('img_data/rock/rock.00008.png'),
#  PosixPath('img_data/country/country.00043.png'),
#  PosixPath('img_data/reggae/reggae.00039.png'),
#  PosixPath('img_data/hiphop/hiphop.00074.png'),
#  PosixPath('img_data/pop/pop.00025.png'),
#  PosixPath('img_data/disco/disco.00005.png'),
#  PosixPath('img_data/classical/classical.00061.png'),
#  PosixPath('img_data/hiphop/hiphop.00024.png'),
#  PosixPath('img_data/blues/blues.00096.png'),
#  PosixPath('img_data/jazz/jazz.00057.png'),
#  PosixPath('img_data/jazz/jazz.00094.png'),
#  PosixPath('img_data/disco/disco.00037.png'),
#  PosixPath('img_data/hiphop/hiphop.00025.png'),
#  PosixPath('img_data/disco/disco.00094.png'),
#  PosixPath('img_data/country/country.00088.png'),
#  PosixPath('img_data/reggae/reggae.00079.png'),
#  PosixPath('img_data/jazz/jazz.00013.png'),
#  PosixPath('img_data/classical/classical.00092.png'),
#  PosixPath('img_data/jazz/jazz.00037.png'),
#  PosixPath('img_data/hiphop/hiphop.00019.png'),
#  PosixPath('img_data/country/country.00015.png'),
#  PosixPath('img_data/hiphop/hiphop.00038.png'),
#  PosixPath('img_data/blues/blues.00005.png'),
#  PosixPath('img_data/country/country.00008.png'),
#  PosixPath('img_data/hiphop/hiphop.00071.png'),
#  PosixPath('img_data/reggae/reggae.00075.png'),
#  PosixPath('img_data/metal/metal.00006.png'),
#  PosixPath('img_data/metal/metal.00088.png'),
#  PosixPath('img_data/jazz/jazz.00048.png'),
#  PosixPath('img_data/reggae/reggae.00007.png'),
#  PosixPath('img_data/pop/pop.00070.png'),
#  PosixPath('img_data/classical/classical.00013.png'),
#  PosixPath('img_data/classical/classical.00089.png'),
#  PosixPath('img_data/blues/blues.00063.png'),
#  PosixPath('img_data/reggae/reggae.00030.png'),
#  PosixPath('img_data/jazz/jazz.00070.png'),
#  PosixPath('img_data/classical/classical.00075.png'),
#  PosixPath('img_data/rock/rock.00026.png'),
#  PosixPath('img_data/metal/metal.00032.png'),
#  PosixPath('img_data/classical/classical.00020.png'),
#  PosixPath('img_data/jazz/jazz.00077.png'),
#  PosixPath('img_data/pop/pop.00077.png'),
#  PosixPath('img_data/disco/disco.00015.png'),
#  PosixPath('img_data/blues/blues.00056.png'),
#  PosixPath('img_data/reggae/reggae.00080.png'),
#  PosixPath('img_data/classical/classical.00002.png'),
#  PosixPath('img_data/pop/pop.00067.png'),
#  PosixPath('img_data/rock/rock.00087.png'),
#  PosixPath('img_data/pop/pop.00007.png'),
#  PosixPath('img_data/hiphop/hiphop.00007.png'),
#  PosixPath('img_data/metal/metal.00019.png'),
#  PosixPath('img_data/pop/pop.00014.png'),
#  PosixPath('img_data/jazz/jazz.00009.png'),
#  PosixPath('img_data/hiphop/hiphop.00085.png'),
#  PosixPath('img_data/hiphop/hiphop.00094.png'),
#  PosixPath('img_data/hiphop/hiphop.00041.png'),
#  PosixPath('img_data/metal/metal.00053.png'),
#  PosixPath('img_data/disco/disco.00012.png'),
#  PosixPath('img_data/jazz/jazz.00017.png'),
#  PosixPath('img_data/hiphop/hiphop.00037.png'),
#  PosixPath('img_data/rock/rock.00033.png'),
#  PosixPath('img_data/disco/disco.00062.png'),
#  PosixPath('img_data/disco/disco.00023.png'),
#  PosixPath('img_data/classical/classical.00033.png'),
#  PosixPath('img_data/country/country.00030.png'),
#  PosixPath('img_data/disco/disco.00055.png'),
#  PosixPath('img_data/blues/blues.00016.png'),
#  PosixPath('img_data/disco/disco.00095.png'),
#  PosixPath('img_data/classical/classical.00071.png'),
#  PosixPath('img_data/classical/classical.00088.png'),
#  PosixPath('img_data/metal/metal.00065.png'),
#  PosixPath('img_data/jazz/jazz.00058.png'),
#  PosixPath('img_data/rock/rock.00067.png'),
#  PosixPath('img_data/hiphop/hiphop.00084.png'),
#  PosixPath('img_data/classical/classical.00044.png'),
#  PosixPath('img_data/pop/pop.00096.png'),
#  PosixPath('img_data/pop/pop.00085.png'),
#  PosixPath('img_data/blues/blues.00069.png'),
#  PosixPath('img_data/reggae/reggae.00016.png'),
#  PosixPath('img_data/hiphop/hiphop.00090.png'),
#  PosixPath('img_data/rock/rock.00060.png'),
#  PosixPath('img_data/blues/blues.00001.png'),
#  PosixPath('img_data/classical/classical.00050.png'),
#  PosixPath('img_data/country/country.00092.png'),
#  PosixPath('img_data/country/country.00064.png'),
#  PosixPath('img_data/blues/blues.00041.png'),
#  PosixPath('img_data/pop/pop.00037.png'),
#  PosixPath('img_data/metal/metal.00037.png'),
#  PosixPath('img_data/reggae/reggae.00066.png'),
#  PosixPath('img_data/hiphop/hiphop.00091.png'),
#  PosixPath('img_data/classical/classical.00093.png'),
#  PosixPath('img_data/reggae/reggae.00010.png'),
#  PosixPath('img_data/country/country.00048.png'),
#  PosixPath('img_data/pop/pop.00028.png'),
#  PosixPath('img_data/pop/pop.00012.png'),
#  PosixPath('img_data/reggae/reggae.00029.png'),
#  PosixPath('img_data/metal/metal.00013.png'),
#  PosixPath('img_data/hiphop/hiphop.00075.png'),
#  PosixPath('img_data/metal/metal.00010.png'),
#  PosixPath('img_data/rock/rock.00036.png'),
#  PosixPath('img_data/metal/metal.00055.png'),
#  PosixPath('img_data/pop/pop.00030.png'),
#  PosixPath('img_data/classical/classical.00051.png'),
#  PosixPath('img_data/metal/metal.00077.png'),
#  PosixPath('img_data/jazz/jazz.00038.png'),
#  PosixPath('img_data/country/country.00061.png'),
#  PosixPath('img_data/disco/disco.00060.png'),
#  PosixPath('img_data/jazz/jazz.00061.png'),
#  PosixPath('img_data/country/country.00070.png'),
#  PosixPath('img_data/country/country.00035.png'),
#  PosixPath('img_data/hiphop/hiphop.00010.png'),
#  PosixPath('img_data/rock/rock.00055.png'),
#  PosixPath('img_data/hiphop/hiphop.00096.png'),
#  PosixPath('img_data/metal/metal.00018.png'),
#  PosixPath('img_data/reggae/reggae.00014.png'),
#  PosixPath('img_data/reggae/reggae.00028.png'),
#  PosixPath('img_data/blues/blues.00010.png'),
#  PosixPath('img_data/metal/metal.00060.png'),
#  PosixPath('img_data/classical/classical.00079.png'),
#  PosixPath('img_data/blues/blues.00032.png'),
#  PosixPath('img_data/disco/disco.00079.png'),
#  PosixPath('img_data/classical/classical.00086.png'),
#  PosixPath('img_data/classical/classical.00024.png'),
#  PosixPath('img_data/country/country.00016.png'),
#  PosixPath('img_data/metal/metal.00056.png'),
#  PosixPath('img_data/hiphop/hiphop.00003.png'),
#  PosixPath('img_data/blues/blues.00000.png'),
#  PosixPath('img_data/classical/classical.00095.png'),
#  PosixPath('img_data/pop/pop.00060.png'),
#  PosixPath('img_data/metal/metal.00024.png'),
#  PosixPath('img_data/metal/metal.00043.png'),
#  PosixPath('img_data/disco/disco.00045.png'),
#  PosixPath('img_data/disco/disco.00020.png'),
#  PosixPath('img_data/rock/rock.00013.png'),
#  PosixPath('img_data/hiphop/hiphop.00047.png'),
#  PosixPath('img_data/pop/pop.00011.png'),
#  PosixPath('img_data/hiphop/hiphop.00048.png'),
#  PosixPath('img_data/reggae/reggae.00078.png'),
#  PosixPath('img_data/blues/blues.00097.png'),
#  PosixPath('img_data/country/country.00018.png'),
#  PosixPath('img_data/metal/metal.00058.png'),
#  PosixPath('img_data/hiphop/hiphop.00034.png'),
#  PosixPath('img_data/hiphop/hiphop.00036.png'),
#  PosixPath('img_data/jazz/jazz.00078.png'),
#  PosixPath('img_data/jazz/jazz.00040.png'),
#  PosixPath('img_data/metal/metal.00046.png'),
#  PosixPath('img_data/rock/rock.00028.png'),
#  PosixPath('img_data/hiphop/hiphop.00035.png'),
#  PosixPath('img_data/jazz/jazz.00020.png'),
#  PosixPath('img_data/disco/disco.00039.png'),
#  PosixPath('img_data/metal/metal.00045.png'),
#  PosixPath('img_data/rock/rock.00080.png'),
#  PosixPath('img_data/rock/rock.00006.png'),
#  PosixPath('img_data/hiphop/hiphop.00057.png'),
#  PosixPath('img_data/jazz/jazz.00032.png'),
#  PosixPath('img_data/classical/classical.00082.png'),
#  PosixPath('img_data/disco/disco.00009.png'),
#  PosixPath('img_data/rock/rock.00062.png'),
#  PosixPath('img_data/metal/metal.00068.png'),
#  PosixPath('img_data/metal/metal.00097.png'),
#  PosixPath('img_data/classical/classical.00034.png'),
#  PosixPath('img_data/hiphop/hiphop.00044.png'),
#  PosixPath('img_data/blues/blues.00086.png'),
#  PosixPath('img_data/hiphop/hiphop.00087.png'),
#  PosixPath('img_data/disco/disco.00090.png'),
#  PosixPath('img_data/pop/pop.00002.png'),
#  PosixPath('img_data/hiphop/hiphop.00081.png'),
#  PosixPath('img_data/hiphop/hiphop.00061.png'),
#  PosixPath('img_data/pop/pop.00003.png'),
#  PosixPath('img_data/pop/pop.00000.png'),
#  PosixPath('img_data/disco/disco.00016.png'),
#  PosixPath('img_data/disco/disco.00081.png'),
#  PosixPath('img_data/blues/blues.00011.png'),
#  PosixPath('img_data/rock/rock.00014.png'),
#  PosixPath('img_data/blues/blues.00027.png'),
#  PosixPath('img_data/hiphop/hiphop.00066.png'),
#  PosixPath('img_data/country/country.00023.png'),
#  PosixPath('img_data/blues/blues.00074.png'),
#  PosixPath('img_data/classical/classical.00076.png'),
#  PosixPath('img_data/blues/blues.00024.png'),
#  PosixPath('img_data/rock/rock.00018.png'),
#  PosixPath('img_data/country/country.00051.png'),
#  PosixPath('img_data/hiphop/hiphop.00095.png'),
#  PosixPath('img_data/classical/classical.00083.png'),
#  PosixPath('img_data/disco/disco.00065.png'),
#  PosixPath('img_data/country/country.00098.png'),
#  PosixPath('img_data/country/country.00084.png'),
#  PosixPath('img_data/metal/metal.00020.png'),
#  PosixPath('img_data/rock/rock.00057.png'),
#  PosixPath('img_data/disco/disco.00044.png'),
#  PosixPath('img_data/classical/classical.00058.png'),
#  PosixPath('img_data/rock/rock.00096.png'),
#  PosixPath('img_data/metal/metal.00034.png'),
#  PosixPath('img_data/country/country.00086.png'),
#  PosixPath('img_data/jazz/jazz.00081.png'),
#  PosixPath('img_data/rock/rock.00019.png'),
#  PosixPath('img_data/hiphop/hiphop.00062.png'),
#  PosixPath('img_data/jazz/jazz.00010.png'),
#  PosixPath('img_data/blues/blues.00037.png'),
#  PosixPath('img_data/disco/disco.00029.png'),
#  PosixPath('img_data/reggae/reggae.00022.png'),
#  PosixPath('img_data/disco/disco.00071.png'),
#  PosixPath('img_data/reggae/reggae.00054.png'),
#  PosixPath('img_data/metal/metal.00052.png'),
#  PosixPath('img_data/blues/blues.00022.png'),
#  PosixPath('img_data/hiphop/hiphop.00064.png'),
#  PosixPath('img_data/metal/metal.00080.png'),
#  PosixPath('img_data/metal/metal.00000.png'),
#  PosixPath('img_data/classical/classical.00031.png'),
#  PosixPath('img_data/rock/rock.00079.png'),
#  PosixPath('img_data/disco/disco.00066.png'),
#  PosixPath('img_data/jazz/jazz.00096.png'),
#  PosixPath('img_data/country/country.00059.png'),
#  PosixPath('img_data/pop/pop.00054.png'),
#  PosixPath('img_data/jazz/jazz.00084.png'),
#  PosixPath('img_data/reggae/reggae.00025.png'),
#  PosixPath('img_data/hiphop/hiphop.00059.png'),
#  PosixPath('img_data/jazz/jazz.00082.png'),
#  PosixPath('img_data/blues/blues.00035.png'),
#  PosixPath('img_data/blues/blues.00015.png'),
#  PosixPath('img_data/hiphop/hiphop.00078.png'),
#  PosixPath('img_data/jazz/jazz.00090.png'),
#  PosixPath('img_data/reggae/reggae.00065.png'),
#  PosixPath('img_data/classical/classical.00035.png'),
#  PosixPath('img_data/reggae/reggae.00051.png'),
#  PosixPath('img_data/jazz/jazz.00097.png'),
#  PosixPath('img_data/jazz/jazz.00014.png'),
#  PosixPath('img_data/hiphop/hiphop.00099.png'),
#  PosixPath('img_data/classical/classical.00029.png'),
#  PosixPath('img_data/disco/disco.00034.png'),
#  PosixPath('img_data/pop/pop.00001.png'),
#  PosixPath('img_data/metal/metal.00012.png'),
#  PosixPath('img_data/jazz/jazz.00088.png'),
#  PosixPath('img_data/pop/pop.00013.png'),
#  PosixPath('img_data/jazz/jazz.00055.png'),
#  PosixPath('img_data/metal/metal.00016.png'),
#  PosixPath('img_data/reggae/reggae.00015.png'),
#  PosixPath('img_data/country/country.00069.png'),
#  PosixPath('img_data/disco/disco.00097.png'),
#  PosixPath('img_data/jazz/jazz.00012.png'),
#  PosixPath('img_data/pop/pop.00045.png'),
#  PosixPath('img_data/metal/metal.00002.png'),
#  PosixPath('img_data/hiphop/hiphop.00068.png'),
#  PosixPath('img_data/pop/pop.00008.png'),
#  PosixPath('img_data/reggae/reggae.00068.png'),
#  PosixPath('img_data/rock/rock.00005.png'),
#  PosixPath('img_data/country/country.00014.png'),
#  PosixPath('img_data/jazz/jazz.00093.png'),
#  PosixPath('img_data/classical/classical.00063.png'),
#  PosixPath('img_data/rock/rock.00024.png'),
#  PosixPath('img_data/jazz/jazz.00000.png'),
#  PosixPath('img_data/blues/blues.00046.png'),
#  PosixPath('img_data/country/country.00013.png'),
#  PosixPath('img_data/metal/metal.00071.png'),
#  PosixPath('img_data/country/country.00046.png'),
#  PosixPath('img_data/reggae/reggae.00093.png'),
#  PosixPath('img_data/disco/disco.00021.png'),
#  PosixPath('img_data/disco/disco.00092.png'),
#  PosixPath('img_data/reggae/reggae.00035.png'),
#  PosixPath('img_data/disco/disco.00076.png'),
#  PosixPath('img_data/pop/pop.00023.png'),
#  PosixPath('img_data/reggae/reggae.00017.png'),
#  PosixPath('img_data/country/country.00052.png'),
#  PosixPath('img_data/hiphop/hiphop.00058.png'),
#  PosixPath('img_data/disco/disco.00070.png'),
#  PosixPath('img_data/blues/blues.00094.png'),
#  PosixPath('img_data/reggae/reggae.00032.png'),
#  PosixPath('img_data/country/country.00042.png'),
#  PosixPath('img_data/disco/disco.00046.png'),
#  PosixPath('img_data/jazz/jazz.00099.png'),
#  PosixPath('img_data/country/country.00034.png'),
#  PosixPath('img_data/country/country.00089.png'),
#  PosixPath('img_data/metal/metal.00067.png'),
#  PosixPath('img_data/classical/classical.00045.png'),
#  PosixPath('img_data/reggae/reggae.00050.png'),
#  PosixPath('img_data/blues/blues.00038.png'),
#  PosixPath('img_data/pop/pop.00034.png'),
#  PosixPath('img_data/disco/disco.00073.png'),
#  PosixPath('img_data/disco/disco.00063.png'),
#  PosixPath('img_data/classical/classical.00091.png'),
#  PosixPath('img_data/jazz/jazz.00011.png'),
#  PosixPath('img_data/metal/metal.00059.png'),
#  PosixPath('img_data/metal/metal.00049.png'),
#  PosixPath('img_data/blues/blues.00030.png'),
#  PosixPath('img_data/pop/pop.00027.png'),
#  PosixPath('img_data/blues/blues.00021.png'),
#  PosixPath('img_data/country/country.00028.png'),
#  PosixPath('img_data/metal/metal.00070.png'),
#  PosixPath('img_data/metal/metal.00095.png'),
#  PosixPath('img_data/rock/rock.00053.png'),
#  PosixPath('img_data/pop/pop.00038.png'),
#  PosixPath('img_data/pop/pop.00066.png'),
#  PosixPath('img_data/jazz/jazz.00008.png'),
#  PosixPath('img_data/disco/disco.00069.png'),
#  PosixPath('img_data/rock/rock.00021.png'),
#  PosixPath('img_data/reggae/reggae.00042.png'),
#  PosixPath('img_data/pop/pop.00072.png'),
#  PosixPath('img_data/reggae/reggae.00086.png'),
#  PosixPath('img_data/metal/metal.00042.png'),
#  PosixPath('img_data/classical/classical.00022.png'),
#  PosixPath('img_data/classical/classical.00038.png'),
#  PosixPath('img_data/blues/blues.00055.png'),
#  PosixPath('img_data/blues/blues.00084.png'),
#  PosixPath('img_data/hiphop/hiphop.00053.png'),
#  PosixPath('img_data/jazz/jazz.00021.png'),
#  PosixPath('img_data/classical/classical.00080.png'),
#  PosixPath('img_data/rock/rock.00063.png'),
#  PosixPath('img_data/pop/pop.00074.png'),
#  PosixPath('img_data/pop/pop.00075.png'),
#  PosixPath('img_data/country/country.00039.png'),
#  PosixPath('img_data/reggae/reggae.00026.png'),
#  PosixPath('img_data/reggae/reggae.00033.png'),
#  PosixPath('img_data/disco/disco.00088.png'),
#  PosixPath('img_data/country/country.00077.png'),
#  PosixPath('img_data/blues/blues.00077.png'),
#  PosixPath('img_data/metal/metal.00035.png'),
#  PosixPath('img_data/blues/blues.00075.png'),
#  PosixPath('img_data/metal/metal.00048.png'),
#  PosixPath('img_data/blues/blues.00085.png'),
#  PosixPath('img_data/jazz/jazz.00080.png'),
#  PosixPath('img_data/blues/blues.00093.png'),
#  PosixPath('img_data/country/country.00095.png'),
#  PosixPath('img_data/classical/classical.00090.png'),
#  PosixPath('img_data/blues/blues.00070.png'),
#  PosixPath('img_data/rock/rock.00069.png'),
#  PosixPath('img_data/reggae/reggae.00005.png'),
#  PosixPath('img_data/metal/metal.00057.png'),
#  PosixPath('img_data/reggae/reggae.00089.png'),
#  PosixPath('img_data/rock/rock.00027.png'),
#  PosixPath('img_data/blues/blues.00071.png'),
#  PosixPath('img_data/classical/classical.00018.png'),
#  PosixPath('img_data/disco/disco.00022.png'),
#  PosixPath('img_data/country/country.00009.png'),
#  PosixPath('img_data/rock/rock.00048.png'),
#  PosixPath('img_data/rock/rock.00092.png'),
#  PosixPath('img_data/blues/blues.00076.png'),
#  PosixPath('img_data/hiphop/hiphop.00060.png'),
#  PosixPath('img_data/reggae/reggae.00060.png'),
#  PosixPath('img_data/pop/pop.00022.png'),
#  PosixPath('img_data/jazz/jazz.00036.png'),
#  PosixPath('img_data/disco/disco.00056.png'),
#  PosixPath('img_data/hiphop/hiphop.00042.png'),
#  PosixPath('img_data/classical/classical.00027.png'),
#  PosixPath('img_data/classical/classical.00037.png'),
#  PosixPath('img_data/blues/blues.00020.png'),
#  PosixPath('img_data/blues/blues.00003.png'),
#  PosixPath('img_data/hiphop/hiphop.00001.png'),
#  PosixPath('img_data/reggae/reggae.00058.png'),
#  PosixPath('img_data/pop/pop.00010.png'),
#  PosixPath('img_data/disco/disco.00014.png'),
#  PosixPath('img_data/pop/pop.00036.png'),
#  PosixPath('img_data/reggae/reggae.00084.png'),
#  PosixPath('img_data/metal/metal.00089.png'),
#  PosixPath('img_data/pop/pop.00021.png'),
#  PosixPath('img_data/blues/blues.00047.png'),
#  PosixPath('img_data/jazz/jazz.00065.png'),
#  PosixPath('img_data/jazz/jazz.00063.png'),
#  PosixPath('img_data/classical/classical.00078.png'),
#  PosixPath('img_data/rock/rock.00035.png'),
#  PosixPath('img_data/disco/disco.00061.png'),
#  PosixPath('img_data/classical/classical.00073.png'),
#  PosixPath('img_data/blues/blues.00026.png'),
#  PosixPath('img_data/hiphop/hiphop.00033.png'),
#  PosixPath('img_data/jazz/jazz.00068.png'),
#  PosixPath('img_data/blues/blues.00098.png'),
#  PosixPath('img_data/jazz/jazz.00066.png'),
#  PosixPath('img_data/country/country.00083.png'),
#  PosixPath('img_data/classical/classical.00009.png'),
#  PosixPath('img_data/classical/classical.00036.png'),
#  PosixPath('img_data/rock/rock.00091.png'),
#  PosixPath('img_data/disco/disco.00072.png'),
#  PosixPath('img_data/hiphop/hiphop.00009.png'),
#  PosixPath('img_data/country/country.00094.png'),
#  PosixPath('img_data/blues/blues.00002.png'),
#  PosixPath('img_data/blues/blues.00062.png'),
#  PosixPath('img_data/jazz/jazz.00073.png'),
#  PosixPath('img_data/disco/disco.00054.png'),
#  PosixPath('img_data/hiphop/hiphop.00079.png'),
#  PosixPath('img_data/rock/rock.00076.png'),
#  PosixPath('img_data/metal/metal.00076.png'),
#  PosixPath('img_data/country/country.00031.png'),
#  PosixPath('img_data/reggae/reggae.00092.png'),
#  PosixPath('img_data/jazz/jazz.00035.png'),
#  PosixPath('img_data/jazz/jazz.00062.png'),
#  PosixPath('img_data/country/country.00012.png'),
#  PosixPath('img_data/country/country.00057.png'),
#  PosixPath('img_data/blues/blues.00091.png'),
#  PosixPath('img_data/classical/classical.00064.png'),
#  PosixPath('img_data/hiphop/hiphop.00012.png'),
#  PosixPath('img_data/country/country.00026.png'),
#  PosixPath('img_data/pop/pop.00093.png'),
#  PosixPath('img_data/reggae/reggae.00077.png'),
#  PosixPath('img_data/classical/classical.00052.png'),
#  PosixPath('img_data/disco/disco.00048.png'),
#  PosixPath('img_data/disco/disco.00008.png'),
#  PosixPath('img_data/metal/metal.00033.png'),
#  PosixPath('img_data/disco/disco.00006.png'),
#  PosixPath('img_data/pop/pop.00024.png'),
#  PosixPath('img_data/rock/rock.00084.png'),
#  PosixPath('img_data/country/country.00025.png'),
#  PosixPath('img_data/blues/blues.00023.png'),
#  PosixPath('img_data/disco/disco.00036.png'),
#  PosixPath('img_data/reggae/reggae.00056.png'),
#  PosixPath('img_data/reggae/reggae.00073.png'),
#  PosixPath('img_data/blues/blues.00068.png'),
#  PosixPath('img_data/hiphop/hiphop.00022.png'),
#  PosixPath('img_data/rock/rock.00031.png'),
#  PosixPath('img_data/blues/blues.00036.png'),
#  PosixPath('img_data/country/country.00075.png'),
#  PosixPath('img_data/classical/classical.00006.png'),
#  PosixPath('img_data/classical/classical.00054.png'),
#  PosixPath('img_data/country/country.00049.png'),
#  PosixPath('img_data/metal/metal.00047.png'),
#  PosixPath('img_data/hiphop/hiphop.00056.png'),
#  PosixPath('img_data/blues/blues.00049.png'),
#  PosixPath('img_data/hiphop/hiphop.00086.png'),
#  PosixPath('img_data/pop/pop.00071.png'),
#  PosixPath('img_data/country/country.00058.png'),
#  PosixPath('img_data/country/country.00093.png'),
#  PosixPath('img_data/blues/blues.00052.png'),
#  PosixPath('img_data/rock/rock.00004.png'),
#  PosixPath('img_data/classical/classical.00096.png'),
#  PosixPath('img_data/jazz/jazz.00086.png'),
#  PosixPath('img_data/country/country.00045.png'),
#  PosixPath('img_data/metal/metal.00093.png'),
#  PosixPath('img_data/classical/classical.00000.png'),
#  PosixPath('img_data/reggae/reggae.00003.png'),
#  PosixPath('img_data/hiphop/hiphop.00089.png'),
#  PosixPath('img_data/hiphop/hiphop.00017.png'),
#  PosixPath('img_data/hiphop/hiphop.00076.png'),
#  PosixPath('img_data/blues/blues.00034.png'),
#  PosixPath('img_data/classical/classical.00014.png'),
#  PosixPath('img_data/reggae/reggae.00018.png'),
#  PosixPath('img_data/reggae/reggae.00097.png'),
#  PosixPath('img_data/classical/classical.00069.png'),
#  PosixPath('img_data/metal/metal.00031.png'),
#  PosixPath('img_data/rock/rock.00047.png'),
#  PosixPath('img_data/pop/pop.00009.png'),
#  PosixPath('img_data/hiphop/hiphop.00016.png'),
#  PosixPath('img_data/metal/metal.00050.png'),
#  PosixPath('img_data/jazz/jazz.00015.png'),
#  PosixPath('img_data/disco/disco.00041.png'),
#  PosixPath('img_data/blues/blues.00039.png'),
#  PosixPath('img_data/jazz/jazz.00002.png'),
#  PosixPath('img_data/disco/disco.00059.png'),
#  PosixPath('img_data/jazz/jazz.00007.png'),
#  PosixPath('img_data/country/country.00060.png'),
#  PosixPath('img_data/pop/pop.00040.png'),
#  PosixPath('img_data/pop/pop.00087.png'),
#  PosixPath('img_data/reggae/reggae.00027.png'),
#  PosixPath('img_data/blues/blues.00009.png'),
#  PosixPath('img_data/blues/blues.00014.png'),
#  PosixPath('img_data/disco/disco.00007.png'),
#  PosixPath('img_data/country/country.00017.png'),
#  PosixPath('img_data/pop/pop.00081.png'),
#  PosixPath('img_data/blues/blues.00082.png'),
#  PosixPath('img_data/reggae/reggae.00088.png'),
#  PosixPath('img_data/jazz/jazz.00026.png'),
#  PosixPath('img_data/pop/pop.00086.png'),
#  PosixPath('img_data/metal/metal.00028.png'),
#  PosixPath('img_data/pop/pop.00042.png'),
#  PosixPath('img_data/classical/classical.00016.png'),
#  PosixPath('img_data/pop/pop.00088.png'),
#  PosixPath('img_data/disco/disco.00031.png'),
#  PosixPath('img_data/pop/pop.00026.png'),
#  PosixPath('img_data/pop/pop.00053.png'),
#  PosixPath('img_data/hiphop/hiphop.00026.png'),
#  PosixPath('img_data/country/country.00090.png'),
#  PosixPath('img_data/classical/classical.00059.png'),
#  PosixPath('img_data/blues/blues.00031.png'),
#  PosixPath('img_data/metal/metal.00092.png'),
#  PosixPath('img_data/hiphop/hiphop.00029.png'),
#  PosixPath('img_data/blues/blues.00066.png'),
#  PosixPath('img_data/country/country.00081.png'),
#  PosixPath('img_data/hiphop/hiphop.00004.png'),
#  PosixPath('img_data/metal/metal.00054.png'),
#  PosixPath('img_data/pop/pop.00052.png'),
#  PosixPath('img_data/classical/classical.00046.png'),
#  PosixPath('img_data/rock/rock.00075.png'),
#  PosixPath('img_data/disco/disco.00049.png'),
#  PosixPath('img_data/reggae/reggae.00006.png'),
#  PosixPath('img_data/rock/rock.00011.png'),
#  PosixPath('img_data/country/country.00002.png'),
#  PosixPath('img_data/blues/blues.00006.png'),
#  PosixPath('img_data/blues/blues.00090.png'),
#  PosixPath('img_data/reggae/reggae.00011.png'),
#  PosixPath('img_data/rock/rock.00085.png'),
#  PosixPath('img_data/metal/metal.00063.png'),
#  PosixPath('img_data/blues/blues.00045.png'),
#  PosixPath('img_data/metal/metal.00094.png'),
#  PosixPath('img_data/jazz/jazz.00060.png'),
#  PosixPath('img_data/pop/pop.00032.png'),
#  PosixPath('img_data/country/country.00096.png'),
#  PosixPath('img_data/disco/disco.00040.png'),
#  PosixPath('img_data/hiphop/hiphop.00083.png'),
#  PosixPath('img_data/hiphop/hiphop.00073.png'),
#  PosixPath('img_data/metal/metal.00051.png'),
#  PosixPath('img_data/hiphop/hiphop.00000.png'),
#  PosixPath('img_data/blues/blues.00089.png'),
#  PosixPath('img_data/pop/pop.00099.png'),
#  PosixPath('img_data/reggae/reggae.00091.png'),
#  PosixPath('img_data/jazz/jazz.00027.png'),
#  PosixPath('img_data/pop/pop.00078.png'),
#  PosixPath('img_data/rock/rock.00088.png'),
#  PosixPath('img_data/pop/pop.00063.png'),
#  PosixPath('img_data/reggae/reggae.00069.png'),
#  PosixPath('img_data/metal/metal.00044.png'),
#  PosixPath('img_data/disco/disco.00035.png'),
#  PosixPath('img_data/rock/rock.00061.png'),
#  PosixPath('img_data/jazz/jazz.00018.png'),
#  PosixPath('img_data/classical/classical.00062.png'),
#  PosixPath('img_data/country/country.00055.png'),
#  PosixPath('img_data/reggae/reggae.00064.png'),
#  PosixPath('img_data/disco/disco.00077.png'),
#  PosixPath('img_data/hiphop/hiphop.00028.png'),
#  PosixPath('img_data/metal/metal.00064.png'),
#  PosixPath('img_data/disco/disco.00043.png'),
#  PosixPath('img_data/reggae/reggae.00023.png'),
#  PosixPath('img_data/disco/disco.00075.png'),
#  PosixPath('img_data/country/country.00007.png'),
#  PosixPath('img_data/country/country.00036.png'),
#  PosixPath('img_data/classical/classical.00057.png'),
#  PosixPath('img_data/disco/disco.00018.png'),
#  PosixPath('img_data/rock/rock.00082.png'),
#  PosixPath('img_data/jazz/jazz.00054.png'),
#  PosixPath('img_data/country/country.00021.png'),
#  PosixPath('img_data/jazz/jazz.00071.png'),
#  PosixPath('img_data/pop/pop.00090.png'),
#  PosixPath('img_data/reggae/reggae.00099.png'),
#  PosixPath('img_data/country/country.00004.png'),
#  PosixPath('img_data/blues/blues.00017.png'),
#  PosixPath('img_data/hiphop/hiphop.00077.png'),
#  PosixPath('img_data/classical/classical.00060.png'),
#  PosixPath('img_data/rock/rock.00001.png'),
#  PosixPath('img_data/country/country.00068.png'),
#  PosixPath('img_data/pop/pop.00017.png'),
#  PosixPath('img_data/reggae/reggae.00024.png'),
#  PosixPath('img_data/jazz/jazz.00072.png'),
#  PosixPath('img_data/rock/rock.00017.png'),
#  PosixPath('img_data/jazz/jazz.00067.png'),
#  PosixPath('img_data/rock/rock.00078.png'),
#  PosixPath('img_data/pop/pop.00095.png'),
#  PosixPath('img_data/jazz/jazz.00095.png'),
#  PosixPath('img_data/blues/blues.00012.png'),
#  PosixPath('img_data/hiphop/hiphop.00027.png'),
#  PosixPath('img_data/classical/classical.00023.png'),
#  PosixPath('img_data/metal/metal.00099.png'),
#  PosixPath('img_data/reggae/reggae.00037.png'),
#  PosixPath('img_data/reggae/reggae.00020.png'),
#  PosixPath('img_data/metal/metal.00014.png'),
#  PosixPath('img_data/pop/pop.00029.png'),
#  PosixPath('img_data/rock/rock.00086.png'),
#  PosixPath('img_data/pop/pop.00069.png'),
#  PosixPath('img_data/disco/disco.00033.png'),
#  PosixPath('img_data/metal/metal.00001.png'),
#  PosixPath('img_data/classical/classical.00011.png'),
#  PosixPath('img_data/disco/disco.00003.png'),
#  PosixPath('img_data/disco/disco.00004.png'),
#  PosixPath('img_data/metal/metal.00040.png'),
#  PosixPath('img_data/reggae/reggae.00012.png'),
#  PosixPath('img_data/blues/blues.00061.png'),
#  PosixPath('img_data/country/country.00037.png'),
#  PosixPath('img_data/hiphop/hiphop.00051.png'),
#  PosixPath('img_data/reggae/reggae.00013.png'),
#  PosixPath('img_data/country/country.00000.png'),
#  PosixPath('img_data/pop/pop.00098.png'),
#  PosixPath('img_data/country/country.00053.png'),
#  PosixPath('img_data/hiphop/hiphop.00049.png'),
#  PosixPath('img_data/country/country.00066.png'),
#  PosixPath('img_data/reggae/reggae.00040.png'),
#  PosixPath('img_data/jazz/jazz.00053.png'),
#  PosixPath('img_data/reggae/reggae.00098.png'),
#  PosixPath('img_data/disco/disco.00019.png'),
#  PosixPath('img_data/disco/disco.00057.png'),
#  PosixPath('img_data/pop/pop.00055.png'),
#  PosixPath('img_data/jazz/jazz.00049.png'),
#  PosixPath('img_data/classical/classical.00026.png'),
#  PosixPath('img_data/disco/disco.00080.png'),
#  PosixPath('img_data/rock/rock.00070.png'),
#  PosixPath('img_data/country/country.00050.png'),
#  PosixPath('img_data/classical/classical.00081.png'),
#  PosixPath('img_data/pop/pop.00051.png'),
#  PosixPath('img_data/pop/pop.00082.png'),
#  PosixPath('img_data/disco/disco.00042.png'),
#  PosixPath('img_data/blues/blues.00079.png'),
#  PosixPath('img_data/metal/metal.00027.png'),
#  PosixPath('img_data/jazz/jazz.00044.png'),
#  PosixPath('img_data/jazz/jazz.00076.png'),
#  PosixPath('img_data/blues/blues.00018.png'),
#  PosixPath('img_data/rock/rock.00056.png'),
#  PosixPath('img_data/country/country.00056.png'),
#  PosixPath('img_data/pop/pop.00048.png'),
#  PosixPath('img_data/disco/disco.00053.png'),
#  PosixPath('img_data/hiphop/hiphop.00054.png'),
#  PosixPath('img_data/classical/classical.00077.png'),
#  PosixPath('img_data/rock/rock.00039.png'),
#  PosixPath('img_data/blues/blues.00054.png'),
#  PosixPath('img_data/blues/blues.00042.png'),
#  PosixPath('img_data/pop/pop.00080.png'),
#  PosixPath('img_data/country/country.00040.png'),
#  PosixPath('img_data/pop/pop.00079.png'),
#  PosixPath('img_data/jazz/jazz.00039.png'),
#  PosixPath('img_data/metal/metal.00030.png'),
#  PosixPath('img_data/pop/pop.00043.png'),
#  PosixPath('img_data/disco/disco.00000.png'),
#  PosixPath('img_data/hiphop/hiphop.00030.png'),
#  PosixPath('img_data/rock/rock.00097.png'),
#  PosixPath('img_data/rock/rock.00071.png'),
#  PosixPath('img_data/rock/rock.00015.png'),
#  PosixPath('img_data/reggae/reggae.00074.png'),
#  PosixPath('img_data/jazz/jazz.00030.png'),
#  PosixPath('img_data/classical/classical.00015.png'),
#  PosixPath('img_data/reggae/reggae.00076.png'),
#  PosixPath('img_data/reggae/reggae.00063.png'),
#  PosixPath('img_data/classical/classical.00021.png'),
#  PosixPath('img_data/country/country.00010.png'),
#  PosixPath('img_data/jazz/jazz.00052.png'),
#  PosixPath('img_data/metal/metal.00025.png'),
#  PosixPath('img_data/disco/disco.00052.png'),
#  PosixPath('img_data/rock/rock.00054.png'),
#  PosixPath('img_data/pop/pop.00019.png'),
#  PosixPath('img_data/metal/metal.00036.png'),
#  PosixPath('img_data/country/country.00011.png'),
#  PosixPath('img_data/jazz/jazz.00028.png'),
#  PosixPath('img_data/blues/blues.00043.png'),
#  PosixPath('img_data/hiphop/hiphop.00014.png'),
#  PosixPath('img_data/hiphop/hiphop.00008.png'),
#  PosixPath('img_data/country/country.00020.png'),
#  PosixPath('img_data/disco/disco.00024.png'),
#  PosixPath('img_data/disco/disco.00002.png'),
#  PosixPath('img_data/rock/rock.00023.png'),
#  PosixPath('img_data/disco/disco.00058.png'),
#  PosixPath('img_data/jazz/jazz.00091.png'),
#  PosixPath('img_data/reggae/reggae.00071.png'),
#  PosixPath('img_data/disco/disco.00083.png'),
#  PosixPath('img_data/pop/pop.00089.png'),
#  PosixPath('img_data/reggae/reggae.00061.png'),
#  PosixPath('img_data/jazz/jazz.00083.png'),
#  PosixPath('img_data/reggae/reggae.00043.png'),
#  PosixPath('img_data/hiphop/hiphop.00039.png'),
#  PosixPath('img_data/reggae/reggae.00002.png'),
#  PosixPath('img_data/disco/disco.00068.png'),
#  PosixPath('img_data/blues/blues.00025.png'),
#  PosixPath('img_data/pop/pop.00006.png'),
#  PosixPath('img_data/country/country.00024.png'),
#  PosixPath('img_data/hiphop/hiphop.00098.png'),
#  PosixPath('img_data/disco/disco.00010.png'),
#  PosixPath('img_data/rock/rock.00073.png'),
#  PosixPath('img_data/pop/pop.00068.png'),
#  PosixPath('img_data/disco/disco.00067.png'),
#  PosixPath('img_data/metal/metal.00029.png'),
#  PosixPath('img_data/hiphop/hiphop.00092.png'),
#  PosixPath('img_data/metal/metal.00083.png'),
#  PosixPath('img_data/hiphop/hiphop.00070.png')]

# %%
#Import images, convert them to grayscale (one uint8 per pixel) and load them into an array
images = []
for spec_path in spectograms:
    image = cv2.imread(str(spec_path))
    image = image[86:630, 90:648]
    cv2.imwrite(str(spec_path), image)
    image = cv2.resize(image, (32, 32))
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    images.append(gray_image)
images = np.array(images, dtype="float") / 255.0
images
# Out:
# array([[[0.46666667, 0.46666667, 0.58431373, ..., 0.56862745,
#          0.59607843, 0.54509804],
#         [0.43921569, 0.6       , 0.61568627, ..., 0.58039216,
#          0.64705882, 0.5372549 ],
#         [0.45882353, 0.43137255, 0.64313725, ..., 0.57254902,
#          0.61568627, 0.62352941],
#         ...,
#         [0.34901961, 0.21176471, 0.38039216, ..., 0.31372549,
#          0.31764706, 0.25490196],
#         [0.28235294, 0.29411765, 0.32941176, ..., 0.32941176,
#          0.46666667, 0.38431373],
#         [0.19215686, 0.18039216, 0.25098039, ..., 0.19607843,
#          0.34901961, 0.2745098 ]],
#
#        [[0.59607843, 0.60392157, 0.58823529, ..., 0.60784314,
#          0.54509804, 0.64705882],
#         [0.56470588, 0.6745098 , 0.61176471, ..., 0.54509804,
#          0.54117647, 0.56470588],
#         [0.61176471, 0.55294118, 0.57254902, ..., 0.64705882,
#          0.51372549, 0.54117647],
#         ...,
#         [0.71764706, 0.6745098 , 0.59607843, ..., 0.58431373,
#          0.59607843, 0.54901961],
#         [0.57254902, 0.53333333, 0.67843137, ..., 0.57254902,
#          0.52156863, 0.44313725],
#         [0.38431373, 0.49411765, 0.43137255, ..., 0.41176471,
#          0.40784314, 0.29803922]],
#
#        [[0.48235294, 0.64705882, 0.6       , ..., 0.64313725,
#          0.61568627, 0.63921569],
#         [0.56470588, 0.60392157, 0.52156863, ..., 0.63137255,
#          0.63921569, 0.64705882],
#         [0.45490196, 0.55294118, 0.61568627, ..., 0.59215686,
#          0.68627451, 0.60784314],
#         ...,
#         [0.36862745, 0.41960784, 0.38039216, ..., 0.39607843,
#          0.36078431, 0.31764706],
#         [0.25490196, 0.25882353, 0.36078431, ..., 0.3372549 ,
#          0.34509804, 0.26666667],
#         [0.27843137, 0.19215686, 0.19607843, ..., 0.2       ,
#          0.11372549, 0.18431373]],
#
#        ...,
#
#        [[0.69019608, 0.65098039, 0.66666667, ..., 0.67058824,
#          0.63529412, 0.71372549],
#         [0.57647059, 0.58431373, 0.7372549 , ..., 0.61568627,
#          0.64705882, 0.6745098 ],
#         [0.52941176, 0.50588235, 0.52156863, ..., 0.56862745,
#          0.56078431, 0.57647059],
#         ...,
#         [0.23921569, 0.16862745, 0.2627451 , ..., 0.20784314,
#          0.27843137, 0.34901961],
#         [0.22352941, 0.30588235, 0.23529412, ..., 0.22745098,
#          0.15686275, 0.10588235],
#         [0.10980392, 0.14117647, 0.18431373, ..., 0.1372549 ,
#          0.13333333, 0.19215686]],
#
#        [[0.67058824, 0.69803922, 0.72941176, ..., 0.71764706,
#          0.70980392, 0.7372549 ],
#         [0.69411765, 0.60784314, 0.74509804, ..., 0.63921569,
#          0.7254902 , 0.69019608],
#         [0.5372549 , 0.61176471, 0.59215686, ..., 0.52941176,
#          0.65882353, 0.63137255],
#         ...,
#         [0.24313725, 0.23137255, 0.23921569, ..., 0.28235294,
#          0.34117647, 0.25098039],
#         [0.16078431, 0.07058824, 0.07058824, ..., 0.15294118,
#          0.14901961, 0.14509804],
#         [0.0627451 , 0.04705882, 0.04705882, ..., 0.03529412,
#          0.05490196, 0.0627451 ]],
#
#        [[0.60392157, 0.50196078, 0.57254902, ..., 0.53333333,
#          0.54901961, 0.50196078],
#         [0.57647059, 0.5372549 , 0.53333333, ..., 0.52941176,
#          0.50980392, 0.57647059],
#         [0.56862745, 0.44705882, 0.61568627, ..., 0.50588235,
#          0.49803922, 0.43921569],
#         ...,
#         [0.4627451 , 0.54117647, 0.36470588, ..., 0.51764706,
#          0.36078431, 0.45882353],
#         [0.31372549, 0.25882353, 0.30980392, ..., 0.28627451,
#          0.29803922, 0.34509804],
#         [0.11764706, 0.1254902 , 0.1372549 , ..., 0.09411765,
#          0.12156863, 0.25490196]]])

# %%
#Create array with correct labels for each spectogram
labels = []
for spec in spectograms:
    labels.append(spec.parts[-2])
labels
# Out:
# ['reggae',
#  'jazz',
#  'reggae',
#  'rock',
#  'rock',
#  'blues',
#  'disco',
#  'hiphop',
#  'rock',
#  'reggae',
#  'jazz',
#  'disco',
#  'classical',
#  'reggae',
#  'country',
#  'hiphop',
#  'metal',
#  'jazz',
#  'pop',
#  'metal',
#  'rock',
#  'classical',
#  'metal',
#  'metal',
#  'pop',
#  'jazz',
#  'jazz',
#  'classical',
#  'jazz',
#  'metal',
#  'blues',
#  'classical',
#  'classical',
#  'pop',
#  'blues',
#  'country',
#  'disco',
#  'jazz',
#  'metal',
#  'reggae',
#  'classical',
#  'classical',
#  'classical',
#  'reggae',
#  'classical',
#  'country',
#  'pop',
#  'reggae',
#  'reggae',
#  'hiphop',
#  'jazz',
#  'country',
#  'pop',
#  'country',
#  'pop',
#  'hiphop',
#  'blues',
#  'country',
#  'pop',
#  'reggae',
#  'country',
#  'metal',
#  'disco',
#  'reggae',
#  'hiphop',
#  'metal',
#  'blues',
#  'jazz',
#  'classical',
#  'blues',
#  'blues',
#  'rock',
#  'blues',
#  'hiphop',
#  'jazz',
#  'hiphop',
#  'disco',
#  'rock',
#  'metal',
#  'classical',
#  'hiphop',
#  'classical',
#  'country',
#  'rock',
#  'hiphop',
#  'hiphop',
#  'metal',
#  'hiphop',
#  'disco',
#  'hiphop',
#  'rock',
#  'classical',
#  'blues',
#  'disco',
#  'pop',
#  'country',
#  'metal',
#  'blues',
#  'hiphop',
#  'hiphop',
#  'classical',
#  'hiphop',
#  'country',
#  'classical',
#  'country',
#  'metal',
#  'rock',
#  'classical',
#  'classical',
#  'metal',
#  'rock',
#  'metal',
#  'pop',
#  'rock',
#  'country',
#  'country',
#  'classical',
#  'disco',
#  'rock',
#  'classical',
#  'rock',
#  'pop',
#  'pop',
#  'blues',
#  'hiphop',
#  'pop',
#  'jazz',
#  'blues',
#  'country',
#  'metal',
#  'reggae',
#  'reggae',
#  'disco',
#  'blues',
#  'pop',
#  'jazz',
#  'rock',
#  'country',
#  'pop',
#  'country',
#  'rock',
#  'reggae',
#  'country',
#  'jazz',
#  'classical',
#  'pop',
#  'metal',
#  'country',
#  'pop',
#  'disco',
#  'rock',
#  'disco',
#  'jazz',
#  'disco',
#  'metal',
#  'classical',
#  'rock',
#  'jazz',
#  'rock',
#  'rock',
#  'reggae',
#  'pop',
#  'country',
#  'reggae',
#  'jazz',
#  'reggae',
#  'reggae',
#  'hiphop',
#  'blues',
#  'metal',
#  'reggae',
#  'metal',
#  'metal',
#  'country',
#  'country',
#  'metal',
#  'jazz',
#  'blues',
#  'hiphop',
#  'disco',
#  'classical',
#  'rock',
#  'jazz',
#  'reggae',
#  'hiphop',
#  'rock',
#  'disco',
#  'reggae',
#  'rock',
#  'jazz',
#  'rock',
#  'pop',
#  'classical',
#  'disco',
#  'reggae',
#  'disco',
#  'hiphop',
#  'pop',
#  'rock',
#  'rock',
#  'rock',
#  'blues',
#  'pop',
#  'disco',
#  'rock',
#  'hiphop',
#  'jazz',
#  'metal',
#  'rock',
#  'classical',
#  'rock',
#  'classical',
#  'reggae',
#  'jazz',
#  'metal',
#  'jazz',
#  'rock',
#  'reggae',
#  'jazz',
#  'rock',
#  'pop',
#  'blues',
#  'metal',
#  'rock',
#  'disco',
#  'pop',
#  'metal',
#  'rock',
#  'blues',
#  'rock',
#  'country',
#  'reggae',
#  'disco',
#  'reggae',
#  'disco',
#  'blues',
#  'country',
#  'reggae',
#  'jazz',
#  'country',
#  'pop',
#  'hiphop',
#  'blues',
#  'pop',
#  'classical',
#  'rock',
#  'metal',
#  'country',
#  'jazz',
#  'metal',
#  'reggae',
#  'reggae',
#  'jazz',
#  'blues',
#  'blues',
#  'reggae',
#  'reggae',
#  'classical',
#  'blues',
#  'metal',
#  'reggae',
#  'blues',
#  'metal',
#  'rock',
#  'reggae',
#  'rock',
#  'rock',
#  'hiphop',
#  'country',
#  'jazz',
#  'disco',
#  'pop',
#  'rock',
#  'rock',
#  'jazz',
#  'rock',
#  'hiphop',
#  'disco',
#  'hiphop',
#  'hiphop',
#  'jazz',
#  'country',
#  'metal',
#  'blues',
#  'blues',
#  'jazz',
#  'disco',
#  'metal',
#  'classical',
#  'classical',
#  'pop',
#  'country',
#  'classical',
#  'classical',
#  'disco',
#  'hiphop',
#  'hiphop',
#  'disco',
#  'jazz',
#  'country',
#  'jazz',
#  'pop',
#  'pop',
#  'blues',
#  'reggae',
#  'pop',
#  'metal',
#  'rock',
#  'jazz',
#  'classical',
#  'disco',
#  'country',
#  'classical',
#  'classical',
#  'jazz',
#  'blues',
#  'country',
#  'pop',
#  'classical',
#  'metal',
#  'metal',
#  'blues',
#  'blues',
#  'pop',
#  'metal',
#  'hiphop',
#  'classical',
#  'rock',
#  'classical',
#  'classical',
#  'reggae',
#  'disco',
#  'metal',
#  'reggae',
#  'rock',
#  'country',
#  'country',
#  'pop',
#  'blues',
#  'blues',
#  'jazz',
#  'disco',
#  'classical',
#  'rock',
#  'reggae',
#  'rock',
#  'rock',
#  'country',
#  'reggae',
#  'hiphop',
#  'pop',
#  'disco',
#  'classical',
#  'hiphop',
#  'blues',
#  'jazz',
#  'jazz',
#  'disco',
#  'hiphop',
#  'disco',
#  'country',
#  'reggae',
#  'jazz',
#  'classical',
#  'jazz',
#  'hiphop',
#  'country',
#  'hiphop',
#  'blues',
#  'country',
#  'hiphop',
#  'reggae',
#  'metal',
#  'metal',
#  'jazz',
#  'reggae',
#  'pop',
#  'classical',
#  'classical',
#  'blues',
#  'reggae',
#  'jazz',
#  'classical',
#  'rock',
#  'metal',
#  'classical',
#  'jazz',
#  'pop',
#  'disco',
#  'blues',
#  'reggae',
#  'classical',
#  'pop',
#  'rock',
#  'pop',
#  'hiphop',
#  'metal',
#  'pop',
#  'jazz',
#  'hiphop',
#  'hiphop',
#  'hiphop',
#  'metal',
#  'disco',
#  'jazz',
#  'hiphop',
#  'rock',
#  'disco',
#  'disco',
#  'classical',
#  'country',
#  'disco',
#  'blues',
#  'disco',
#  'classical',
#  'classical',
#  'metal',
#  'jazz',
#  'rock',
#  'hiphop',
#  'classical',
#  'pop',
#  'pop',
#  'blues',
#  'reggae',
#  'hiphop',
#  'rock',
#  'blues',
#  'classical',
#  'country',
#  'country',
#  'blues',
#  'pop',
#  'metal',
#  'reggae',
#  'hiphop',
#  'classical',
#  'reggae',
#  'country',
#  'pop',
#  'pop',
#  'reggae',
#  'metal',
#  'hiphop',
#  'metal',
#  'rock',
#  'metal',
#  'pop',
#  'classical',
#  'metal',
#  'jazz',
#  'country',
#  'disco',
#  'jazz',
#  'country',
#  'country',
#  'hiphop',
#  'rock',
#  'hiphop',
#  'metal',
#  'reggae',
#  'reggae',
#  'blues',
#  'metal',
#  'classical',
#  'blues',
#  'disco',
#  'classical',
#  'classical',
#  'country',
#  'metal',
#  'hiphop',
#  'blues',
#  'classical',
#  'pop',
#  'metal',
#  'metal',
#  'disco',
#  'disco',
#  'rock',
#  'hiphop',
#  'pop',
#  'hiphop',
#  'reggae',
#  'blues',
#  'country',
#  'metal',
#  'hiphop',
#  'hiphop',
#  'jazz',
#  'jazz',
#  'metal',
#  'rock',
#  'hiphop',
#  'jazz',
#  'disco',
#  'metal',
#  'rock',
#  'rock',
#  'hiphop',
#  'jazz',
#  'classical',
#  'disco',
#  'rock',
#  'metal',
#  'metal',
#  'classical',
#  'hiphop',
#  'blues',
#  'hiphop',
#  'disco',
#  'pop',
#  'hiphop',
#  'hiphop',
#  'pop',
#  'pop',
#  'disco',
#  'disco',
#  'blues',
#  'rock',
#  'blues',
#  'hiphop',
#  'country',
#  'blues',
#  'classical',
#  'blues',
#  'rock',
#  'country',
#  'hiphop',
#  'classical',
#  'disco',
#  'country',
#  'country',
#  'metal',
#  'rock',
#  'disco',
#  'classical',
#  'rock',
#  'metal',
#  'country',
#  'jazz',
#  'rock',
#  'hiphop',
#  'jazz',
#  'blues',
#  'disco',
#  'reggae',
#  'disco',
#  'reggae',
#  'metal',
#  'blues',
#  'hiphop',
#  'metal',
#  'metal',
#  'classical',
#  'rock',
#  'disco',
#  'jazz',
#  'country',
#  'pop',
#  'jazz',
#  'reggae',
#  'hiphop',
#  'jazz',
#  'blues',
#  'blues',
#  'hiphop',
#  'jazz',
#  'reggae',
#  'classical',
#  'reggae',
#  'jazz',
#  'jazz',
#  'hiphop',
#  'classical',
#  'disco',
#  'pop',
#  'metal',
#  'jazz',
#  'pop',
#  'jazz',
#  'metal',
#  'reggae',
#  'country',
#  'disco',
#  'jazz',
#  'pop',
#  'metal',
#  'hiphop',
#  'pop',
#  'reggae',
#  'rock',
#  'country',
#  'jazz',
#  'classical',
#  'rock',
#  'jazz',
#  'blues',
#  'country',
#  'metal',
#  'country',
#  'reggae',
#  'disco',
#  'disco',
#  'reggae',
#  'disco',
#  'pop',
#  'reggae',
#  'country',
#  'hiphop',
#  'disco',
#  'blues',
#  'reggae',
#  'country',
#  'disco',
#  'jazz',
#  'country',
#  'country',
#  'metal',
#  'classical',
#  'reggae',
#  'blues',
#  'pop',
#  'disco',
#  'disco',
#  'classical',
#  'jazz',
#  'metal',
#  'metal',
#  'blues',
#  'pop',
#  'blues',
#  'country',
#  'metal',
#  'metal',
#  'rock',
#  'pop',
#  'pop',
#  'jazz',
#  'disco',
#  'rock',
#  'reggae',
#  'pop',
#  'reggae',
#  'metal',
#  'classical',
#  'classical',
#  'blues',
#  'blues',
#  'hiphop',
#  'jazz',
#  'classical',
#  'rock',
#  'pop',
#  'pop',
#  'country',
#  'reggae',
#  'reggae',
#  'disco',
#  'country',
#  'blues',
#  'metal',
#  'blues',
#  'metal',
#  'blues',
#  'jazz',
#  'blues',
#  'country',
#  'classical',
#  'blues',
#  'rock',
#  'reggae',
#  'metal',
#  'reggae',
#  'rock',
#  'blues',
#  'classical',
#  'disco',
#  'country',
#  'rock',
#  'rock',
#  'blues',
#  'hiphop',
#  'reggae',
#  'pop',
#  'jazz',
#  'disco',
#  'hiphop',
#  'classical',
#  'classical',
#  'blues',
#  'blues',
#  'hiphop',
#  'reggae',
#  'pop',
#  'disco',
#  'pop',
#  'reggae',
#  'metal',
#  'pop',
#  'blues',
#  'jazz',
#  'jazz',
#  'classical',
#  'rock',
#  'disco',
#  'classical',
#  'blues',
#  'hiphop',
#  'jazz',
#  'blues',
#  'jazz',
#  'country',
#  'classical',
#  'classical',
#  'rock',
#  'disco',
#  'hiphop',
#  'country',
#  'blues',
#  'blues',
#  'jazz',
#  'disco',
#  'hiphop',
#  'rock',
#  'metal',
#  'country',
#  'reggae',
#  'jazz',
#  'jazz',
#  'country',
#  'country',
#  'blues',
#  'classical',
#  'hiphop',
#  'country',
#  'pop',
#  'reggae',
#  'classical',
#  'disco',
#  'disco',
#  'metal',
#  'disco',
#  'pop',
#  'rock',
#  'country',
#  'blues',
#  'disco',
#  'reggae',
#  'reggae',
#  'blues',
#  'hiphop',
#  'rock',
#  'blues',
#  'country',
#  'classical',
#  'classical',
#  'country',
#  'metal',
#  'hiphop',
#  'blues',
#  'hiphop',
#  'pop',
#  'country',
#  'country',
#  'blues',
#  'rock',
#  'classical',
#  'jazz',
#  'country',
#  'metal',
#  'classical',
#  'reggae',
#  'hiphop',
#  'hiphop',
#  'hiphop',
#  'blues',
#  'classical',
#  'reggae',
#  'reggae',
#  'classical',
#  'metal',
#  'rock',
#  'pop',
#  'hiphop',
#  'metal',
#  'jazz',
#  'disco',
#  'blues',
#  'jazz',
#  'disco',
#  'jazz',
#  'country',
#  'pop',
#  'pop',
#  'reggae',
#  'blues',
#  'blues',
#  'disco',
#  'country',
#  'pop',
#  'blues',
#  'reggae',
#  'jazz',
#  'pop',
#  'metal',
#  'pop',
#  'classical',
#  'pop',
#  'disco',
#  'pop',
#  'pop',
#  'hiphop',
#  'country',
#  'classical',
#  'blues',
#  'metal',
#  'hiphop',
#  'blues',
#  'country',
#  'hiphop',
#  'metal',
#  'pop',
#  'classical',
#  'rock',
#  'disco',
#  'reggae',
#  'rock',
#  'country',
#  'blues',
#  'blues',
#  'reggae',
#  'rock',
#  'metal',
#  'blues',
#  'metal',
#  'jazz',
#  'pop',
#  'country',
#  'disco',
#  'hiphop',
#  'hiphop',
#  'metal',
#  'hiphop',
#  'blues',
#  'pop',
#  'reggae',
#  'jazz',
#  'pop',
#  'rock',
#  'pop',
#  'reggae',
#  'metal',
#  'disco',
#  'rock',
#  'jazz',
#  'classical',
#  'country',
#  'reggae',
#  'disco',
#  'hiphop',
#  'metal',
#  'disco',
#  'reggae',
#  'disco',
#  'country',
#  'country',
#  'classical',
#  'disco',
#  'rock',
#  'jazz',
#  'country',
#  'jazz',
#  'pop',
#  'reggae',
#  'country',
#  'blues',
#  'hiphop',
#  'classical',
#  'rock',
#  'country',
#  'pop',
#  'reggae',
#  'jazz',
#  'rock',
#  'jazz',
#  'rock',
#  'pop',
#  'jazz',
#  'blues',
#  'hiphop',
#  'classical',
#  'metal',
#  'reggae',
#  'reggae',
#  'metal',
#  'pop',
#  'rock',
#  'pop',
#  'disco',
#  'metal',
#  'classical',
#  'disco',
#  'disco',
#  'metal',
#  'reggae',
#  'blues',
#  'country',
#  'hiphop',
#  'reggae',
#  'country',
#  'pop',
#  'country',
#  'hiphop',
#  'country',
#  'reggae',
#  'jazz',
#  'reggae',
#  'disco',
#  'disco',
#  'pop',
#  'jazz',
#  'classical',
#  'disco',
#  'rock',
#  'country',
#  'classical',
#  'pop',
#  'pop',
#  'disco',
#  'blues',
#  'metal',
#  'jazz',
#  'jazz',
#  'blues',
#  'rock',
#  'country',
#  'pop',
#  'disco',
#  'hiphop',
#  'classical',
#  'rock',
#  'blues',
#  'blues',
#  'pop',
#  'country',
#  'pop',
#  'jazz',
#  'metal',
#  'pop',
#  'disco',
#  'hiphop',
#  'rock',
#  'rock',
#  'rock',
#  'reggae',
#  'jazz',
#  'classical',
#  'reggae',
#  'reggae',
#  'classical',
#  'country',
#  'jazz',
#  'metal',
#  'disco',
#  'rock',
#  'pop',
#  'metal',
#  'country',
#  'jazz',
#  'blues',
#  'hiphop',
#  'hiphop',
#  'country',
#  'disco',
#  'disco',
#  'rock',
#  'disco',
#  'jazz',
#  'reggae',
#  'disco',
#  'pop',
#  'reggae',
#  'jazz',
#  'reggae',
#  'hiphop',
#  'reggae',
#  'disco',
#  'blues',
#  'pop',
#  'country',
#  'hiphop',
#  'disco',
#  'rock',
#  'pop',
#  'disco',
#  'metal',
#  'hiphop',
#  'metal',
#  'hiphop']
